# %%
import utils
from utils import *
import pandas as pd
import numpy as np
import random
import time

# %%
# this is code to make a more useful df(s) for evaluation
# we read the sentences from files which include test words and make a big df with useful columns
utils.fix_reproducibility()

corpus = load_dataset("bennexx/jp_sentences")
corpus = corpus['train'].to_pandas()

target_filename = '/data/enrico_benedetti/nihongoexample/data/targets/target_words.csv'
system_dirs = ['/data/enrico_benedetti/nihongoexample/evaluation/outputs/retrieval/', '/data/enrico_benedetti/nihongoexample/evaluation/outputs/generation/llm_jp/', '/data/enrico_benedetti/nihongoexample/evaluation/outputs/generation/chatgpt/']
output_dir = "/data/enrico_benedetti/nihongoexample/evaluation/outputs/all"

df_target = pd.read_csv(target_filename)

# %%
target_levels = ['N1', 'N3', 'N5']
dfs = []
k=5
for target_level in target_levels:
    
    for system_id, system_dir in enumerate(system_dirs, start=1):

        for i, data in df_target.iterrows():
        
            target_word = data['target_word']
            context_sentence = data['context_sentence']
            # read the file which is like sys_dir + tw_tl_.csv
            sentence_file = f"{system_dir}{target_word}_{target_level}_.csv"
            # assign also split if in val or test based on the df_target
            
            try:
                df = pd.read_csv(sentence_file) # damn retrieval is different format
                # remove context sentence from sentence column... will need to change the scoring function... or at least the output.
                # actually no, all systems have it in first position, just the other column types that is different
                df['system_id'] = system_id
                df['context_sentence'] = context_sentence
                df['target_word'] = target_word
                df['target_level'] = target_level
                if data['is_test_reduced']:
                    df['split'] = 'test'
                else: df['split'] = 'val'
                #df.to_csv(sentence_file, index=False)
                dfs.append(df.loc[1:k])
            except FileNotFoundError as e:
                # pass
                print(e)

combined_df = pd.concat(dfs, ignore_index=True)

# %%
human_eval_only = combined_df['split'] == 'test'
combined_df[human_eval_only].to_csv('/data/enrico_benedetti/nihongoexample/data/targets/combined_human_eval', index=False)

# %%
lens = [len(df) for df in dfs]

# %%
df_info = pd.DataFrame({'len': lens})
df_info.value_counts()
# Out:
# len
# 5      553
# 1        4
# 4        4
# 2        3
# 3        3
# Name: count, dtype: int64

# %%
# check that the generated outputs are not in the dataset

# %%
dup = combined_df['sentence'].isin(corpus['sentence'])
sys1 = combined_df['system_id'] == 1
sys2 = combined_df['system_id'] == 2
sys3 = combined_df['system_id'] == 3
pretty_subset = ['split','sentence','target_word', 'target_level', 'context_sentence','system_id']

# %%
print('Outputs which are also present in the corpus:')
print(combined_df[dup].value_counts(subset=['system_id','split']))
# Out:
# Outputs which are also present in the corpus:
# system_id  split
# 1          val      795
#            test     150
# 2          val        1
# 3          val        1
# Name: count, dtype: int64

# %%
print('Generation outputs which are also present in the corpus:')
display(combined_df[dup & ~sys1][pretty_subset])
# which source are they from
corpus_source = load_dataset("bennexx/jp_sentences", "sources", split='train').to_pandas()
corpus_source = corpus_source.rename(columns={'Unnamed: 0': 'start'})
# add source back to the corpus
for i, source_id in enumerate(corpus_source['start'].tolist()):
    corpus.loc[source_id, 'source'] = corpus_source.loc[i,'source']
corpus['source'] = corpus['source'].ffill()

print("Sources for those sentences")
corpus_dup = corpus['sentence'].isin(combined_df.loc[dup & ~sys1, 'sentence'])
display(corpus[corpus_dup])
# Out:
# Generation outputs which are also present in the corpus:
#      split   sentence target_word target_level              context_sentence  \
# 1366   val   彼は立っていた。          立つ           N3  しかし自分ながら、なぜそんなに腹が立つのだか分からない。
# 2581   val  情報が欲しいです。          情報           N5         水の色が真赤になる情報があったであります。
#
#       system_id
# 1366          2
# 2581          3
# Sources for those sentences
#          sentence   source
# 107529  情報が欲しいです。    jpwac
# 305073   彼は立っていた。  tatoeba

# %%
# how many sentences where produced in total
print("Per system coverage of getting enough sentences on all words")
system_coverage = combined_df.value_counts(subset=['system_id']) / (len(df_target) * k * len(target_levels))
print(system_coverage)

print("Per system and level coverage of getting enough sentences on all words")
system_level_coverage = combined_df.value_counts(subset=['system_id', 'target_level']) / (len(df_target) * k)
print(system_level_coverage)


print("Which words produced less than k sentences")
word_level_coverage = combined_df.value_counts(subset=['split','system_id', 'target_level', 'target_word'])
bad_coverage = word_level_coverage[word_level_coverage < 5]

print(bad_coverage)
print("How many queries are without enough sentences:")
print(bad_coverage.count())

# investigating hajime, we see that it changed the kanji so it did not recognize it.
# Out:
# Per system coverage of getting enough sentences on all words
# system_id
# 1            1.000000
# 2            0.987302
# 3            0.975661
# Name: count, dtype: float64
# Per system and level coverage of getting enough sentences on all words
# system_id  target_level
# 1          N1              1.000000
#            N3              1.000000
#            N5              1.000000
# 2          N3              0.990476
#            N5              0.987302
#            N1              0.984127
# 3          N5              0.984127
#            N3              0.977778
#            N1              0.965079
# Name: count, dtype: float64
# Which words produced less than k sentences
# split  system_id  target_level  target_word
# val    3          N5            立つ             4
#        2          N1            前              4
#        3          N5            可能             4
#                   N3            子供             4
#                                 飛ぶ             3
#                                 立つ             3
#                                 可能             3
#                   N5            子供             2
#                   N1            飛ぶ             2
#        2          N3            初め             2
#                   N1            初め             1
#        3          N1            子供             1
#                                 可能             1
#        2          N5            初め             1
# Name: count, dtype: int64
# How many queries are without enough sentences:
# 14

# %%
print("Unsolved queries by system")
display(bad_coverage.groupby(by='system_id').aggregate(len))
print("Unsolved queries by system and target level")
display(bad_coverage.groupby(by=['system_id', 'target_level']).aggregate(len)) # pretty much uniformly

# percentage wise 
total_queries_per_system = len(df_target) * len(target_levels)
print(f"Each system is queried {total_queries_per_system} times")
unsolved_queries = bad_coverage.groupby(by='system_id').aggregate(len) / total_queries_per_system
display(1 - unsolved_queries)
# Out:
# Unsolved queries by system
# system_id
# 2     4
# 3    10
# Name: count, dtype: int64
# Unsolved queries by system and target level
# system_id  target_level
# 2          N1              2
#            N3              1
#            N5              1
# 3          N1              3
#            N3              4
#            N5              3
# Name: count, dtype: int64
# Each system is queried 189 times
# system_id
# 2    0.978836
# 3    0.947090
# Name: count, dtype: float64

# %%
# Group by 'system_id' and count duplicates within each group
dup_count_by_system = combined_df[combined_df.duplicated(subset=['sentence'], keep=False)]
# Sort the counts in descending order
sorted_dup_count = dup_count_by_system.value_counts(subset=['split','system_id']).sort_values(ascending=False)

# Display the results

print('duplicated sentences by system')
sorted_dup_count = dup_count_by_system.value_counts(subset=['system_id'], sort=False)
print(sorted_dup_count.to_string())

print('duplicated sentences by system (percentage)')
sorted_dup_count = dup_count_by_system.value_counts(subset=['system_id'], sort=False) / (len(df_target) * k * len(target_levels))
print(sorted_dup_count.to_string())

print('duplicated sentences by system and split')
sorted_dup_count = dup_count_by_system.value_counts(subset=['split','system_id']).sort_values(ascending=False)
print(sorted_dup_count.to_string())

### we have that GPT3.5 is the system that reuses the most sentences for different levels
# 84 out of
# Out:
# duplicated sentences by system
# system_id
# 1            22
# 2             4
# 3            84
# duplicated sentences by system (percentage)
# system_id
# 1            0.023280
# 2            0.004233
# 3            0.088889
# duplicated sentences by system and split
# split  system_id
# val    3            72
#        1            22
# test   3            12
# val    2             4

# %%
df_dup_out.iloc[0]
# Out:
# split                                                             val
# sentence            ■ドーナツフライオイルにはメーカーと共同開発した植物性のオイルを使用することで、油分の吸収を...
# target_word                                                      サッパリ
# target_level                                                       N3
# context_sentence                    また聞こえてくる君尾の笑い声、はなやかで明るくてサッパリしている。
# system_id                                                           1
# Name: 1225, dtype: object

# %%
print('Outputs that are duplicates:')
df_dup_out = combined_df[combined_df.duplicated(subset=['sentence'], keep=False)][pretty_subset].sort_values(by='sentence')
print(df_dup_out.to_string())

#print(df_dup_out.value_counts(subset=['sentence','target_word','target_level', 'system_id'], sort=True).to_string())
# Out:
# Outputs that are duplicates:
#      split                                                                 sentence target_word target_level                        context_sentence  system_id
# 1225   val  ■ドーナツフライオイルにはメーカーと共同開発した植物性のオイルを使用することで、油分の吸収を抑え、ベタつかずサッパリと食べやすく仕上げました。        サッパリ           N3       また聞こえてくる君尾の笑い声、はなやかで明るくてサッパリしている。          1
# 2160   val  ■ドーナツフライオイルにはメーカーと共同開発した植物性のオイルを使用することで、油分の吸収を抑え、ベタつかずサッパリと食べやすく仕上げました。        サッパリ           N5       また聞こえてくる君尾の笑い声、はなやかで明るくてサッパリしている。          1
# 1611   val                                             あの会社との関係を築くために、多くの時間を費やしました。          関係           N3   あなたの御関係なすっておいでになる男の事を、ある偶然の機会で承知しました。          3
# 2546   val                                             あの会社との関係を築くために、多くの時間を費やしました。          関係           N5   あなたの御関係なすっておいでになる男の事を、ある偶然の機会で承知しました。          3
# 1845   val                                                   このお茶はサッパリしていて、夏にぴったりだ。        サッパリ           N3       また聞こえてくる君尾の笑い声、はなやかで明るくてサッパリしている。          3
# 910    val                                                   このお茶はサッパリしていて、夏にぴったりだ。        サッパリ           N1       また聞こえてくる君尾の笑い声、はなやかで明るくてサッパリしている。          3
# 1639   val                                                 この新商品は、若者の市場をターゲットにしている。          市場           N3             この四月以来市場には、前代未聞だと云う恐慌が来ている。          3
# 703    val                                                 この新商品は、若者の市場をターゲットにしている。          市場           N1             この四月以来市場には、前代未聞だと云う恐慌が来ている。          3
# 660    val                                                           そのビルはとても大きいです。         大きい           N1       その結果同じ画像をGIFにした場合よりサイズが大きくなってしまう。          3
# 2525   val                                                           そのビルはとても大きいです。         大きい           N5       その結果同じ画像をGIFにした場合よりサイズが大きくなってしまう。          3
# 1591   val                                                           そのビルはとても大きいです。         大きい           N3       その結果同じ画像をGIFにした場合よりサイズが大きくなってしまう。          3
# 1610   val                                                      その二人の関係は秘密に包まれています。          関係           N3   あなたの御関係なすっておいでになる男の事を、ある偶然の機会で承知しました。          3
# 2545   val                                                      その二人の関係は秘密に包まれています。          関係           N5   あなたの御関係なすっておいでになる男の事を、ある偶然の機会で承知しました。          3
# 1707  test                                         その商品を売るかどうかは、消費者の需要による場合が決め手となる。          場合           N3             この闘いは今日の場合では大概は容易ならぬ苦闘だからだ。          3
# 773   test                                         その商品を売るかどうかは、消費者の需要による場合が決め手となる。          場合           N1             この闘いは今日の場合では大概は容易ならぬ苦闘だからだ。          3
# 1830   val                                               その鋭い感覚により、彼女は問題の核心を見つけ出した。          鋭い           N3       鋭い鎌でどんな物も真っ二つにしてしまうがこんにゃくだけは切れない。          3
# 895    val                                               その鋭い感覚により、彼女は問題の核心を見つけ出した。          鋭い           N1       鋭い鎌でどんな物も真っ二つにしてしまうがこんにゃくだけは切れない。          3
# 1221   val                            と尋ねると、「バリバリ、インタビューの練習をしてました」と述べ、観客の大爆笑を誘っている。        バリバリ           N3                自分の将来の目的に向かってバリバリ勉強していた。          1
# 2157   val                            と尋ねると、「バリバリ、インタビューの練習をしてました」と述べ、観客の大爆笑を誘っている。        バリバリ           N5                自分の将来の目的に向かってバリバリ勉強していた。          1
# 911    val                                                  サッパリした気分で新しい一日をスタートしよう。        サッパリ           N1       また聞こえてくる君尾の笑い声、はなやかで明るくてサッパリしている。          3
# 1846   val                                                  サッパリした気分で新しい一日をスタートしよう。        サッパリ           N3       また聞こえてくる君尾の笑い声、はなやかで明るくてサッパリしている。          3
# 2706   val                                                  ドラマを見ると、感情に引き込まれてしまいます。          見る           N5           婆さんは三百弗の小切手を見ると、急に愛想がよくなりました。          3
# 1772   val                                                  ドラマを見ると、感情に引き込まれてしまいます。          見る           N3           婆さんは三百弗の小切手を見ると、急に愛想がよくなりました。          3
# 2163   val                                             ニコールは、一体どういうことだかサッパリ分からなかった。        サッパリ           N5       また聞こえてくる君尾の笑い声、はなやかで明るくてサッパリしている。          1
# 1228   val                                             ニコールは、一体どういうことだかサッパリ分からなかった。        サッパリ           N3       また聞こえてくる君尾の笑い声、はなやかで明るくてサッパリしている。          1
# 1839   val                                             バリバリ働きながら、新しいビジネスモデルを考えています。        バリバリ           N3                自分の将来の目的に向かってバリバリ勉強していた。          3
# 904    val                                             バリバリ働きながら、新しいビジネスモデルを考えています。        バリバリ           N1                自分の将来の目的に向かってバリバリ勉強していた。          3
# 906    val                                            バリバリ練習したおかげで、音楽のコンテストで優勝しました。        バリバリ           N1                自分の将来の目的に向かってバリバリ勉強していた。          3
# 1841   val                                            バリバリ練習したおかげで、音楽のコンテストで優勝しました。        バリバリ           N3                自分の将来の目的に向かってバリバリ勉強していた。          3
# 1843   val                                       プロジェクトを成功させるために、バリバリのリーダーシップが必要です。        バリバリ           N3                自分の将来の目的に向かってバリバリ勉強していた。          3
# 908    val                                       プロジェクトを成功させるために、バリバリのリーダーシップが必要です。        バリバリ           N1                自分の将来の目的に向かってバリバリ勉強していた。          3
# 985    val                                           例外的に、性的な関係を求める者が集まる危険な場所も存在する。          関係           N3   あなたの御関係なすっておいでになる男の事を、ある偶然の機会で承知しました。          1
# 1108   val                                           例外的に、性的な関係を求める者が集まる危険な場所も存在する。          場所           N3                    一人のこらず死んだような場所もあります。          1
# 1771   val                                       公園で子供たちが楽しそうに遊んでいるのを見ると、私も笑顔になります。          見る           N3           婆さんは三百弗の小切手を見ると、急に愛想がよくなりました。          3
# 2705   val                                       公園で子供たちが楽しそうに遊んでいるのを見ると、私も笑顔になります。          見る           N5           婆さんは三百弗の小切手を見ると、急に愛想がよくなりました。          3
# 2159   val                                                  味は鶏モモ肉に似ておりサッパリしているという。        サッパリ           N5       また聞こえてくる君尾の笑い声、はなやかで明るくてサッパリしている。          1
# 1224   val                                                  味は鶏モモ肉に似ておりサッパリしているという。        サッパリ           N3       また聞こえてくる君尾の笑い声、はなやかで明るくてサッパリしている。          1
# 847    val                                              学生たちは、教育の質の向上を求める運動を展開している。         求める           N1          囚人虐待事件への対応などの影響から退任を求める声が出始めた。          3
# 1781   val                                              学生たちは、教育の質の向上を求める運動を展開している。         求める           N3          囚人虐待事件への対応などの影響から退任を求める声が出始めた。          3
# 1786   val                                                 小さなものでも、心からの感謝の気持ちは大切です。          もの           N3        軽量なものでは5kgを切るような車体を作成することも可能である。          3
# 2720   val                                                 小さなものでも、心からの感謝の気持ちは大切です。          もの           N5        軽量なものでは5kgを切るような車体を作成することも可能である。          3
# 1773   val                                             山の頂上からの景色を見ると、息をのむほど美しかったです。          見る           N3           婆さんは三百弗の小切手を見ると、急に愛想がよくなりました。          3
# 2707   val                                             山の頂上からの景色を見ると、息をのむほど美しかったです。          見る           N5           婆さんは三百弗の小切手を見ると、急に愛想がよくなりました。          3
# 1609   val                                                         彼との関係は古くからの友情です。          関係           N3   あなたの御関係なすっておいでになる男の事を、ある偶然の機会で承知しました。          3
# 2544   val                                                         彼との関係は古くからの友情です。          関係           N5   あなたの御関係なすっておいでになる男の事を、ある偶然の機会で承知しました。          3
# 1594   val                                                       彼の夢は大きい成功を収めることです。         大きい           N3       その結果同じ画像をGIFにした場合よりサイズが大きくなってしまう。          3
# 663    val                                                       彼の夢は大きい成功を収めることです。         大きい           N1       その結果同じ画像をGIFにした場合よりサイズが大きくなってしまう。          3
# 1581   val                                                         彼の言葉は深い意味を含んでいる。          意味           N3     この意味で、会話は、彼の意図通り、方向を転換したと云っても差支えない。          3
# 2515   val                                                         彼の言葉は深い意味を含んでいる。          意味           N5     この意味で、会話は、彼の意図通り、方向を転換したと云っても差支えない。          3
# 894    val                                              彼の鋭い観察力は、常に物事の本質を見抜くことができる。          鋭い           N1       鋭い鎌でどんな物も真っ二つにしてしまうがこんにゃくだけは切れない。          3
# 1829   val                                              彼の鋭い観察力は、常に物事の本質を見抜くことができる。          鋭い           N3       鋭い鎌でどんな物も真っ二つにしてしまうがこんにゃくだけは切れない。          3
# 797   test                                                              彼はいつも仕事が早い。          早い           N1            一番早く人口が20万人に到達した都市であったと思われる。          3
# 1731  test                                                              彼はいつも仕事が早い。          早い           N3            一番早く人口が20万人に到達した都市であったと思われる。          3
# 1840   val                                              彼はバリバリのエンジニアで、プログラミングに夢中です。        バリバリ           N3                自分の将来の目的に向かってバリバリ勉強していた。          3
# 905    val                                              彼はバリバリのエンジニアで、プログラミングに夢中です。        バリバリ           N1                自分の将来の目的に向かってバリバリ勉強していた。          3
# 1596   val                                                 彼はピアノを教えるために毎週教室に通っています。         教える           N3                 英吉利語を教える報酬は僅かに月額六十円である。          3
# 665    val                                                 彼はピアノを教えるために毎週教室に通っています。         教える           N1                 英吉利語を教える報酬は僅かに月額六十円である。          3
# 817    val                                           彼は外で遊ぶことが大好きで、いつも公園で友達と遊んでいます。           外           N1                学校の外では「広場の王様」とあだ名されたという。          3
# 1751   val                                           彼は外で遊ぶことが大好きで、いつも公園で友達と遊んでいます。           外           N3                学校の外では「広場の王様」とあだ名されたという。          3
# 661    val                                                           彼は大きい声で歌っています。         大きい           N1       その結果同じ画像をGIFにした場合よりサイズが大きくなってしまう。          3
# 1592   val                                                           彼は大きい声で歌っています。         大きい           N3       その結果同じ画像をGIFにした場合よりサイズが大きくなってしまう。          3
# 2526   val                                                           彼は大きい声で歌っています。         大きい           N5       その結果同じ画像をGIFにした場合よりサイズが大きくなってしまう。          3
# 842   test                                                          彼は常に自信を持って行動する。          持つ           N1  またお箸の手が違ったよといえば、すぐ右に直すけれど、少しするとまた左に持つ。          3
# 1780  test                                                          彼は常に自信を持って行動する。          持つ           N3  またお箸の手が違ったよといえば、すぐ右に直すけれど、少しするとまた左に持つ。          3
# 742    val                                                     彼は強い意志を持って夢を追い続けている。          強い           N1                       本人の意思が強ければ止められるわ。          3
# 1676   val                                                     彼は強い意志を持って夢を追い続けている。          強い           N3                       本人の意思が強ければ止められるわ。          3
# 879    val                                                            彼は病院の壁に絵を掛ける。         掛ける           N1                       罪人はおとなしく椅子に腰を掛ける。          3
# 1814   val                                                            彼は病院の壁に絵を掛ける。         掛ける           N3                       罪人はおとなしく椅子に腰を掛ける。          3
# 2490  test                                                         彼は相手の発言に敏感に反応した。          相手           N5       また、東西お互いに相手を非難するプロパガンダ放送を流し合っていた。          3
# 1556  test                                                         彼は相手の発言に敏感に反応した。          相手           N3       また、東西お互いに相手を非難するプロパガンダ放送を流し合っていた。          3
# 1686   val                                                          彼は突然会議室から出て行った。          出る           N3                 成東の停車場をおりて、町形をした家並みを出る。          3
# 752    val                                                          彼は突然会議室から出て行った。          出る           N1                 成東の停車場をおりて、町形をした家並みを出る。          3
# 2190   val                                                       彼は給料を上げてくれと上司に頼んだ。         上げる           N5     その汗を流して手に入れたものを、ただで他に上げるということは出来ない。          2
# 1254   val                                                       彼は給料を上げてくれと上司に頼んだ。         上げる           N3     その汗を流して手に入れたものを、ただで他に上げるということは出来ない。          2
# 671    val                                                       彼は自分の将来について真剣に考える。         考える           N1                      私は母の愛というものに就いて考える。          3
# 2539   val                                                       彼は自分の将来について真剣に考える。         考える           N5                      私は母の愛というものに就いて考える。          3
# 1604   val                                                       彼は自分の将来について真剣に考える。         考える           N3                      私は母の愛というものに就いて考える。          3
# 1766   val                                                        彼女の努力が認められて、昇進した。         認める           N3                          これを認める研究者は少ない。          3
# 2700   val                                                        彼女の努力が認められて、昇進した。         認める           N5                          これを認める研究者は少ない。          3
# 832    val                                                        彼女の努力が認められて、昇進した。         認める           N1                          これを認める研究者は少ない。          3
# 909    val                                              彼女はサッパリした性格で、いつも明るく人を元気にする。        サッパリ           N1       また聞こえてくる君尾の笑い声、はなやかで明るくてサッパリしている。          3
# 1844   val                                              彼女はサッパリした性格で、いつも明るく人を元気にする。        サッパリ           N3       また聞こえてくる君尾の笑い声、はなやかで明るくてサッパリしている。          3
# 41     val                                             技術を教えること一つを取ってみてもそれだけではすまない。         教える           N1                 英吉利語を教える報酬は僅かに月額六十円である。          1
# 61     val                                             技術を教えること一つを取ってみてもそれだけではすまない。          技術           N1               技術は何によらず練習するより他に上達する道はない。          1
# 1226   val                                                          特に後半なんかはサッパリです。        サッパリ           N3       また聞こえてくる君尾の笑い声、はなやかで明るくてサッパリしている。          1
# 2161   val                                                          特に後半なんかはサッパリです。        サッパリ           N5       また聞こえてくる君尾の笑い声、はなやかで明るくてサッパリしている。          1
# 2492  test                                                        相手の意見を尊重することが大切だ。          相手           N5       また、東西お互いに相手を非難するプロパガンダ放送を流し合っていた。          3
# 1558  test                                                        相手の意見を尊重することが大切だ。          相手           N3       また、東西お互いに相手を非難するプロパガンダ放送を流し合っていた。          3
# 1557  test                                                  相手を信頼できるかどうかを見極める必要がある。          相手           N3       また、東西お互いに相手を非難するプロパガンダ放送を流し合っていた。          3
# 2491  test                                                  相手を信頼できるかどうかを見極める必要がある。          相手           N5       また、東西お互いに相手を非難するプロパガンダ放送を流し合っていた。          3
# 666    val                                                 私のおばあさんは孫に釣りの楽しみを教えています。         教える           N1                 英吉利語を教える報酬は僅かに月額六十円である。          3
# 1597   val                                                 私のおばあさんは孫に釣りの楽しみを教えています。         教える           N3                 英吉利語を教える報酬は僅かに月額六十円である。          3
# 1988   val                                                               私の前に立たないで。          立つ           N5            しかし自分ながら、なぜそんなに腹が立つのだか分からない。          1
# 2073   val                                                               私の前に立たないで。           前           N5        原作では創造主の下僕でもあり、モコナの前では謙遜した態度をとる。          1
# 1220   val                         節子は車の知識を身につけ、セールスレディとしてバリバリ仕事をして、会社で優秀な営業成績を上げる。        バリバリ           N3                自分の将来の目的に向かってバリバリ勉強していた。          1
# 2156   val                         節子は車の知識を身につけ、セールスレディとしてバリバリ仕事をして、会社で優秀な営業成績を上げる。        バリバリ           N5                自分の将来の目的に向かってバリバリ勉強していた。          1
# 1638   val                                         自動車業界の市場は、電気自動車の登場によって大きく変化している。          市場           N3             この四月以来市場には、前代未聞だと云う恐慌が来ている。          3
# 702    val                                         自動車業界の市場は、電気自動車の登場によって大きく変化している。          市場           N1             この四月以来市場には、前代未聞だと云う恐慌が来ている。          3
# 907    val                                              試験前にバリバリ勉強すれば、合格できる自信があります。        バリバリ           N1                自分の将来の目的に向かってバリバリ勉強していた。          3
# 1842   val                                              試験前にバリバリ勉強すれば、合格できる自信があります。        バリバリ           N3                自分の将来の目的に向かってバリバリ勉強していた。          3
# 547    val                                          軽いものでは5kgを切るような車体を作成することも可能である。          もの           N1        軽量なものでは5kgを切るような車体を作成することも可能である。          2
# 2413   val                                          軽いものでは5kgを切るような車体を作成することも可能である。          もの           N5        軽量なものでは5kgを切るような車体を作成することも可能である。          2
# 1804   val                                                週末には友達と一緒にプログラムの勉強に時間を積む。          積む           N3        その後プロに転向すると、地元大阪を中心に大会へ出場し経験を積む。          3
# 2740   val                                                週末には友達と一緒にプログラムの勉強に時間を積む。          積む           N5        その後プロに転向すると、地元大阪を中心に大会へ出場し経験を積む。          3
# 2162   val                   醤油単体に比べサッパリとした味を出す事ができ、主に唐揚げやハンバーグなどの肉料理に対するたれとして使われる。        サッパリ           N5       また聞こえてくる君尾の笑い声、はなやかで明るくてサッパリしている。          1
# 1227   val                   醤油単体に比べサッパリとした味を出す事ができ、主に唐揚げやハンバーグなどの肉料理に対するたれとして使われる。        サッパリ           N3       また聞こえてくる君尾の笑い声、はなやかで明るくてサッパリしている。          1
# 1593   val                                                        長距離バスには大きい窓があります。         大きい           N3       その結果同じ画像をGIFにした場合よりサイズが大きくなってしまう。          3
# 662    val                                                        長距離バスには大きい窓があります。         大きい           N1       その結果同じ画像をGIFにした場合よりサイズが大きくなってしまう。          3
# 2158   val                                           鳥越俊太郎さんもお元気なって、バリバリ現場取材なさってます。        バリバリ           N5                自分の将来の目的に向かってバリバリ勉強していた。          1
# 1223   val                                           鳥越俊太郎さんもお元気なって、バリバリ現場取材なさってます。        バリバリ           N3                自分の将来の目的に向かってバリバリ勉強していた。          1

# %%
combined_df['system_id'].value_counts()
# Out:
# system_id
# 1    945
# 2    933
# 3    922
# Name: count, dtype: int64

# %%
combined_df[dup]
# Out:
#                                                sentence      index  \
# 0     外交経験が無い素人2人組の外交は半年が空費され、相手から一方的に条件を呑まされる寸前になり失...  1684583.0
# 1     ドイツの戦略爆撃機とイギリス、アメリカの戦略爆撃機の合計の多い国家が少ない国家（ドイツ又はイ...  5505912.0
# 2              これはその言葉を発した側が、その発言を持って相手を貶めようとしているためである。  1508529.0
# 3     カトコフの主張は、一般的に穏健なものではあったが、ひとたびや筆を執るや否や、痛烈に相手を批判...  3917741.0
# 4     また、両派ともに相手の絶滅を主張し、小型の出刃包丁やハンマーなどを使用した襲撃を続けたため逮...  1694412.0
# ...                                                 ...        ...
# 2175                                        立つと足の裏の上です。   116062.0
# 2176                  車で長時間移動する時は、時々止まって足を伸ばさなければいけません。   329759.0
# 2177                                        座って足を組んでみて。   366685.0
# 2178                              寝てるときにさ、足がガクンってなる時ない？   311716.0
# 2581                                          情報が欲しいです。        NaN
#
#       index_hits level  level_score  sense_score  quality_score  \
# 0            NaN    N1          1.0     0.725103       0.862552
# 1            NaN    N1          1.0     0.728948       0.864474
# 2            NaN    N1          1.0     0.773248       0.886624
# 3            NaN    N1          1.0     0.778942       0.889471
# 4            NaN    N1          1.0     0.781091       0.890545
# ...          ...   ...          ...          ...            ...
# 2175         NaN    N5          1.0     0.722260       0.861130
# 2176         NaN    N5          1.0     0.760393       0.880197
# 2177         NaN    N5          1.0     0.761630       0.880815
# 2178         NaN    N5          1.0     0.691118       0.845559
# 2581         NaN   NaN          NaN          NaN            NaN
#
#                                           sentence_docs  \
# 0     外交経験が無い素人2人組の外交は半年が空費され、相手から一方的に条件を呑まされる寸前になり失...
# 1     ドイツの戦略爆撃機とイギリス、アメリカの戦略爆撃機の合計の多い国家が少ない国家（ドイツ又はイ...
# 2              これはその言葉を発した側が、その発言を持って相手を貶めようとしているためである。
# 3     カトコフの主張は、一般的に穏健なものではあったが、ひとたびや筆を執るや否や、痛烈に相手を批判...
# 4     また、両派ともに相手の絶滅を主張し、小型の出刃包丁やハンマーなどを使用した襲撃を続けたため逮...
# ...                                                 ...
# 2175                                        立つと足の裏の上です。
# 2176                  車で長時間移動する時は、時々止まって足を伸ばさなければいけません。
# 2177                                        座って足を組んでみて。
# 2178                              寝てるときにさ、足がガクンってなる時ない？
# 2581                                                NaN
#
#                                              parse_tree  \
# 0        (ADJ_ROOT (NOUN_nsubj NOUN_compound ADP_case))
# 1     (NOUN_ROOT\n  (PROPN_nmod\n    (PROPN_nmod\n  ...
# 2     (NOUN_ROOT\n  (VERB_acl\n    (PRON_nsubj ADP_c...
# 3     (VERB_ROOT\n  (NOUN_advcl\n    (NOUN_nsubj (NO...
# 4     (VERB_ROOT\n  (VERB_obl\n    CCONJ_cc\n    PUN...
# ...                                                 ...
# 2175  (NOUN_ROOT\n  (VERB_acl SCONJ_mark)\n  (NOUN_n...
# 2176  (VERB_ROOT\n  (NOUN_obl\n    (VERB_acl (NOUN_o...
# 2177  (VERB_ROOT\n  (VERB_advcl (VERB_advcl SCONJ_ma...
# 2178  (ADJ_ROOT\n  (NOUN_obl\n    (VERB_acl\n      (...
# 2581                                                NaN
#
#                                               tokenized  ...  \
# 0     ['外交', '経験', 'が', '無い', '素人', '2', '人組', 'の', ...  ...
# 1     ['ドイツ', 'の', '戦略', '爆撃機', 'と', 'イギリス', '、', 'ア...  ...
# 2     ['これ', 'は', 'その', '言葉', 'を', '発し', 'た', '側', '...  ...
# 3     ['カトコフ', 'の', '主張', 'は', '、', '一般的', 'に', '穏健'...  ...
# 4     ['また', '、', '両派', 'とも', 'に', '相手', 'の', '絶滅', ...  ...
# ...                                                 ...  ...
# 2175    ['立つ', 'と', '足', 'の', '裏', 'の', '上', 'です', '。']  ...
# 2176  ['車', 'で', '長時間', '移動', 'する', '時', 'は', '、', '...  ...
# 2177    ['座っ', 'て', '足', 'を', '組ん', 'で', 'み', 'て', '。']  ...
# 2178  ['寝', 'てる', 'とき', 'に', 'さ', '、', '足', 'が', 'ガク...  ...
# 2581                                                NaN  ...
#
#       lexical_div_score  div_score  total_score  system_id  \
# 0              0.939792   0.969896     0.916224          1
# 1              0.890657   0.945328     0.904901          1
# 2              0.884993   0.915592     0.901108          1
# 3              0.871871   0.889312     0.889392          1
# 4              0.866260   0.860982     0.875764          1
# ...                 ...        ...          ...        ...
# 2175           0.964286   0.859808     0.860469          1
# 2176           0.947443   0.831914     0.856055          1
# 2177           0.914468   0.803476     0.842146          1
# 2178           0.910281   0.794028     0.819794          1
# 2581                NaN        NaN          NaN          3
#
#                        context_sentence target_word target_level block_id  \
# 0     また、東西お互いに相手を非難するプロパガンダ放送を流し合っていた。          相手           N1      0.0
# 1     また、東西お互いに相手を非難するプロパガンダ放送を流し合っていた。          相手           N1      0.0
# 2     また、東西お互いに相手を非難するプロパガンダ放送を流し合っていた。          相手           N1      0.0
# 3     また、東西お互いに相手を非難するプロパガンダ放送を流し合っていた。          相手           N1      0.0
# 4     また、東西お互いに相手を非難するプロパガンダ放送を流し合っていた。          相手           N1      0.0
# ...                                 ...         ...          ...      ...
# 2175                 ハードルに手や足をかけても問題ない。           足           N5      NaN
# 2176                 ハードルに手や足をかけても問題ない。           足           N5      NaN
# 2177                 ハードルに手や足をかけても問題ない。           足           N5      NaN
# 2178                 ハードルに手や足をかけても問題ない。           足           N5      NaN
# 2581              水の色が真赤になる情報があったであります。          情報           N5      NaN
#
#       random_ordering split
# 0                   E  test
# 1                   E  test
# 2                   E  test
# 3                   E  test
# 4                   E  test
# ...               ...   ...
# 2175              NaN   val
# 2176              NaN   val
# 2177              NaN   val
# 2178              NaN   val
# 2581              NaN   val
#
# [947 rows x 21 columns]

# %%
only_test = df_target['is_test_reduced']
df_target[only_test]
assert(len(df_target[only_test]) == 10)

# %%
#test = combined_df.groupby(by=['target_level','target_word','context_sentence', 'system_id'], group_keys=False).apply(lambda x: x)

# %%
#combined_df.groupby(by=['target_level','target_word','context_sentence', 'system_id']).get_group(('N1', target_word, context_sentence, 1))
